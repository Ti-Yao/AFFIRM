# %%
import sys
sys.path.append('../')
from AFFIRM import *

# %%
data_path = '/media/tina/Seagate Expansion Drive/Work/hirid/'
label_name = 'AF'
affirm = AFFIRM(data_path, label_name)

# %% [markdown]
# ## preprocess hirid

# %%
preprocess_params = {
    'rename_dict' : {'temp':'Temperature','mean.arterial.pressure':'MAP','systolic.arterial.pressure':'Systolic BP',
               'diastolic.arterial.pressure':'Diastolic BP'},
    'parameter_dict' : {'Circadian_rhythm': [4, 10]},
     
    'filter_range': [0.01, 0.99]
}
affirm.fit_preprocess(**preprocess_params)
affirm.preprocess()
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]

# %% [markdown]
# ## prepare

# %%
prepare_params = {
    'predict_hours': 6,                 
    'grouping_hours': 1,
    'group_how_list': ['max'],#,'min'],
    'group_label_within':120, 
    'rolling': False,
    'take_first': False,
    'percentage_patients_per_variable': 0.8, 
    'avg_values_each': 2,
    'feature_names': [],
    'pharma_quantile' : 0.75,
    'include_patients':[],
    'exclude_patients': [],#'Surgical Cardiovascular'
    
}
affirm.fit_prepare(**prepare_params)
# affirm.prepare()

# %% [markdown]
# ## predict

# %%
def create_keras():  
    model = Sequential()
    model.add(Dense(8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[AUC(curve="PR", name='auprc')])        
    return model

keras_model = create_keras()
keras_model = KerasClassifier(build_fn= create_keras, verbose=0)
keras_model._estimator_type = "classifier"
predict_params = {
    'models': {
#         'Logistic Regression': LogisticRegression(random_state=0)
#           , 'Keras':keras_model,
#           'Random Forest':RandomForestClassifier(max_depth=4, random_state=0),
#             'LightGBM':lgb.LGBMClassifier(boosting_type='gbdt', objective='binary'),
#         'Optimised XGBoost': xgb.XGBClassifier(base_score=0.5, 
#                                                   colsample_bylevel=1, 
#                                                   colsample_bytree=1,
#                                                   gamma=0, 
#                                                   learning_rate=0.1, 
#                                                   max_delta_step=0, 
#                                                   max_depth=10,
#                                                   min_child_weight=1, 
#                                                   n_estimators=100, 
#                                                   nthread=-1,
#                                                   objective='binary:logistic', 
#                                                   reg_alpha=0, 
#                                                   reg_lambda=1,
#                                                   scale_pos_weight=1, 
#                                                   eval_metric = 'aucpr',
#                                                   seed=0, 
#                                                   missing = 1,
#                                                   subsample=1,
#                                                   use_label_encoder=False), 
        'XGBoost': xgb.XGBClassifier(objective = "binary:logistic",
           eval_metric = "aucpr",use_label_encoder=False)
         },
    'colors' : {'LightGBM': '#4e8542',# dark green
          'Baseline': '#ff9292', #pink
          'Logistic Regression':'#eccd1c', #gold
          'Random Forest': '#6aa4c8', #sky blye
          'XGBoost': '#ff833c', #organ
            'Optimised XGBoost': '#fcaf83',
          'Keras': '#8dd8d3' #light blue
         },
    'n_splits': 2,
    'keep_top_features': 20,
    'intervention_features': ['Potassium', 'Magnesium']
     
}
affirm.fit_predict(**predict_params)

# %%
df = affirm.df
for column in affirm.obs_variables:
# Out:
#                            Base_excess_in_Arterial_blood_by_calculation_max  \
# patientid hours_since_adm
# 148       0                                                            -0.7
#           1                                                             NaN
#           2                                                             NaN
#           3                                                             NaN
#           4                                                             NaN
# ...                                                                     ...
# 33900     250                                                           NaN
#           251                                                           NaN
#           252                                                           NaN
#           253                                                           NaN
#           254                                                           NaN
#
#                            Bicarbonate_Molesvolume_in_Arterial_blood_max  \
# patientid hours_since_adm
# 148       0                                                         23.6
#           1                                                          NaN
#           2                                                          NaN
#           3                                                          NaN
#           4                                                          NaN
# ...                                                                  ...
# 33900     250                                                        NaN
#           251                                                        NaN
#           252                                                        NaN
#           253                                                        NaN
#           254                                                        NaN
#
#                            C_reactive_protein_Massvolume_in_Serum_or_Plasma_max  \
# patientid hours_since_adm
# 148       0                                                              NaN
#           1                                                              NaN
#           2                                                              NaN
#           3                                                              NaN
#           4                                                              NaN
# ...                                                                      ...
# 33900     250                                                            NaN
#           251                                                            NaN
#           252                                                            NaN
#           253                                                            NaN
#           254                                                            NaN
#
#                            Calciumionized_Molesvolume_in_Blood_max  \
# patientid hours_since_adm
# 148       0                                                   1.21
#           1                                                    NaN
#           2                                                    NaN
#           3                                                    NaN
#           4                                                    NaN
# ...                                                            ...
# 33900     250                                                  NaN
#           251                                                  NaN
#           252                                                  NaN
#           253                                                  NaN
#           254                                                  NaN
#
#                            Carbon_dioxide_Partial_pressure_in_Arterial_blood_max  \
# patientid hours_since_adm
# 148       0                                                             37.0
#           1                                                              NaN
#           2                                                              NaN
#           3                                                              NaN
#           4                                                              NaN
# ...                                                                      ...
# 33900     250                                                            NaN
#           251                                                            NaN
#           252                                                            NaN
#           253                                                            NaN
#           254                                                            NaN
#
#                            CarboxyhemoglobinHemoglobintotal_in_Arterial_blood_max  \
# patientid hours_since_adm
# 148       0                                                              1.0
#           1                                                              NaN
#           2                                                              NaN
#           3                                                              NaN
#           4                                                              NaN
# ...                                                                      ...
# 33900     250                                                            NaN
#           251                                                            NaN
#           252                                                            NaN
#           253                                                            NaN
#           254                                                            NaN
#
#                            Chloride_Molesvolume_in_Blood_max  \
# patientid hours_since_adm
# 148       0                                            105.0
#           1                                              NaN
#           2                                              NaN
#           3                                              NaN
#           4                                              NaN
# ...                                                      ...
# 33900     250                                            NaN
#           251                                            NaN
#           252                                            NaN
#           253                                            NaN
#           254                                            NaN
#
#                            Creatinine_Molesvolume_in_Blood_max  \
# patientid hours_since_adm
# 148       0                                                NaN
#           1                                                NaN
#           2                                                NaN
#           3                                                NaN
#           4                                                NaN
# ...                                                        ...
# 33900     250                                              NaN
#           251                                              NaN
#           252                                              NaN
#           253                                              NaN
#           254                                              NaN
#
#                            Diastolic BP_max  Fluid_balance_max  ...  \
# patientid hours_since_adm                                       ...
# 148       0                           105.0         103.000000  ...
#           1                            57.0         116.733002  ...
#           2                            58.0         122.865997  ...
#           3                            52.0         633.366028  ...
#           4                            56.0                NaN  ...
# ...                                     ...                ...  ...
# 33900     250                          75.0        2528.488525  ...
#           251                           NaN        2723.390869  ...
#           252                          58.0                NaN  ...
#           253                          60.0         380.000000  ...
#           254                          67.0                NaN  ...
#
#                            pH_of_Arterial_blood_max  ST_elevation_max  \
# patientid hours_since_adm
# 148       0                                   7.412               NaN
#           1                                     NaN               NaN
#           2                                     NaN               NaN
#           3                                     NaN               NaN
#           4                                     NaN               NaN
# ...                                             ...               ...
# 33900     250                                   NaN               NaN
#           251                                   NaN               NaN
#           252                                   NaN               NaN
#           253                                   NaN               NaN
#           254                                   NaN               NaN
#
#                            Urea_Molesvolume_in_Venous_blood_max  \
# patientid hours_since_adm
# 148       0                                                 NaN
#           1                                                 NaN
#           2                                                 NaN
#           3                                                 NaN
#           4                                                 NaN
# ...                                                         ...
# 33900     250                                               NaN
#           251                                               NaN
#           252                                               NaN
#           253                                               NaN
#           254                                               NaN
#
#                            INR_in_Blood_by_Coagulation_assay_max  sex   age  \
# patientid hours_since_adm
# 148       0                                                  NaN  NaN   NaN
#           1                                                  NaN  NaN   NaN
#           2                                                  NaN  NaN   NaN
#           3                                                  NaN  NaN   NaN
#           4                                                  NaN  NaN   NaN
# ...                                                          ...  ...   ...
# 33900     250                                                NaN  1.0  85.0
#           251                                                NaN  1.0  85.0
#           252                                                NaN  1.0  85.0
#           253                                                NaN  1.0  85.0
#           254                                                NaN  1.0  85.0
#
#                                  bmi  patient  AF  Interventions
# patientid hours_since_adm
# 148       0                      NaN      NaN   0              0
#           1                      NaN      NaN   0              0
#           2                      NaN      NaN   0              0
#           3                      NaN      NaN   0              0
#           4                      NaN      NaN   0              0
# ...                              ...      ...  ..            ...
# 33900     250              24.489796  33900.0   0              0
#           251              24.489796  33900.0   0              0
#           252              24.489796  33900.0   0              0
#           253              24.489796  33900.0   0              0
#           254              24.489796  33900.0   0              0
#
# [1884030 rows x 46 columns]

# %%
affirm.df.AF.value_counts()
# Out:
# 0    1698646
# 1     185384
# Name: AF, dtype: int64

# %%
affirm.initial_prediction()
# Out:
# 0.6356395724307593

# %%
pred_df = affirm.predictions_df

# %%
pred_df['False Pos'] = pred_df.where((pred_df['y_test'] == 0) & (pred_df['y_pred'] == 1) & (pred_df['Interventions'] == 1) ).Interventions.replace(np.nan, 0)

# %%
def calc_auprc(y_test,y_pred):
    precision,recall,  _ = precision_recall_curve(y_test, y_pred) # calculate recall and precision
    AUPRC = auc(recall, precision) # calculate area under the precision-recall curve
    return AUPRC

pred_df = affirm.predictions_df

calc_auprc(pred_df.y_test, pred_df.Interventions)

pred_df['new_y_test'] = pred_df[['y_test','Interventions']].max(axis = 1).astype(int)
pred_df['false_pos_y_test'] =pred_df[['y_test','False Pos']].max(axis = 1).astype(int)
print(calc_auprc(pred_df.new_y_test, pred_df.y_pred))
print(calc_auprc(pred_df.false_pos_y_test, pred_df.y_pred))
print(calc_auprc(pred_df.y_test, pred_df.y_pred))
# Out:
# 0.5980053777724568
# 0.6441579300505218
# 0.6356395724307593

# %%
affirm.df.columns
# Out:
# Index(['Base_excess_in_Arterial_blood_by_calculation_max',
#        'Bicarbonate_Molesvolume_in_Arterial_blood_max',
#        'C_reactive_protein_Massvolume_in_Serum_or_Plasma_max',
#        'Calciumionized_Molesvolume_in_Blood_max',
#        'Carbon_dioxide_Partial_pressure_in_Arterial_blood_max',
#        'CarboxyhemoglobinHemoglobintotal_in_Arterial_blood_max',
#        'Chloride_Molesvolume_in_Blood_max',
#        'Creatinine_Molesvolume_in_Blood_max', 'Diastolic BP_max',
#        'Fluid_balance_max', 'Glasgow_Coma_Score_eye_opening_subscore_max',
#        'Glasgow_Coma_Score_motor_response_subscore_max',
#        'Glasgow_Coma_Score_verbal_response_subscore_max',
#        'Glucose_Molesvolume_in_Serum_or_Plasma_max', 'Heart_rate_max',
#        'Hemoglobin_Massvolume_in_Arterial_blood_max',
#        'Hemoglobin_Massvolume_in_Blood_max', 'Hourly_urine_volume_max',
#        'Infusion_of_saline_solution_max',
#        'Lactate_Massvolume_in_Arterial_blood_max',
#        'Leukocytes_volume_in_Blood_max', 'MAP_max',
#        'MCHC_Massvolume_in_Cord_blood_max', 'MCH_Entitic_mass_max',
#        'MCV_Entitic_volume_max',
#        'MethemoglobinHemoglobintotal_in_Arterial_blood_max',
#        'Oxygen_Partial_pressure_in_Arterial_blood_max',
#        'Oxygen_administration_by_nasal_cannula_max',
#        'Oxygen_saturation_in_Arterial_blood_max',
#        'Peripheral_oxygen_saturation_max', 'Platelets_volume_in_Blood_max',
#        'Potassium_Molesvolume_in_Blood_max', 'Respiratory_rate_max',
#        'Richmond_agitationsedation_scale_max',
#        'Sodium_Molesvolume_in_Blood_max', 'Systolic BP_max',
#        'pH_of_Arterial_blood_max', 'ST_elevation_max',
#        'Urea_Molesvolume_in_Venous_blood_max',
#        'INR_in_Blood_by_Coagulation_assay_max', 'sex', 'age', 'bmi', 'patient',
#        'AF', 'Interventions'],
#       dtype='object')

# %%
affirm.predict()
# Out:
# 0.54892955195996
#
# It took 2.25 minutes to evaluate XGBoost

# %%
affirm.plot_feature_importances('XGBoost')

# %%
len(affirm.df.columns)
# Out:
# 45

# %%
affirm.df.reset_index().patientid.values
# Out:
# array([  148,   148,   148, ..., 33900, 33900, 33900])
